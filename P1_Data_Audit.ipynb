# %% [markdown]
# # Data Loading

# %%
import pandas as pd
df_main = pd.read_csv('df_main_output.csv')

# %%
df_benchmark = pd.read_csv('benchmark_data.csv')

# %%
df_benchmark
# Out:
#          VIX  T-Bill_13W_Yield  10Y_Treasury_Yield  Credit_Spread
# 0  20.025819          0.999144            2.501993       1.502848

# %% [markdown]
# # Inspect Data Structure and Basic Information

# %%
df_main.head()
df_main.head(10)
# Out:
#          VIX  T-Bill_13W_Yield  10Y_Treasury_Yield  Credit_Spread    Regime  \
# 0  12.445680          1.029864            2.702186       1.672322   Low Vol
# 1  24.238080          1.085886            2.297124       1.211238  High Vol
# 2  28.867150          0.934233            2.935775       2.001542  High Vol
# 3  21.062232          0.860070            2.564964       1.704894  High Vol
# 4  23.385069          1.243889            2.868615       1.624726  High Vol
# 5  29.901249          1.256203            2.185474       0.929272  High Vol
# 6  24.624739          0.480617            2.658078       2.177461  High Vol
# 7  26.243766          1.180873            2.556627       1.375755  High Vol
# 8  30.611449          0.846289            2.419048       1.572759  High Vol
# 9  31.219941          1.199295            2.489578       1.290283  High Vol
#
#    VIX_lag_1  VIX_lag_5  VIX_lag_10  T-Bill_13W_Yield_lag_1  \
# 0  26.975503  20.800619   16.753388                0.987509
# ...

# %%
df_benchmark.head()
# Out:
#          VIX  T-Bill_13W_Yield  10Y_Treasury_Yield  Credit_Spread
# 0  20.025819          0.999144            2.501993       1.502848

# %%
df_benchmark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   VIX                 1 non-null      float64
#  1   T-Bill_13W_Yield    1 non-null      float64
#  2   10Y_Treasury_Yield  1 non-null      float64
#  3   Credit_Spread       1 non-null      float64
# dtypes: float64(4)
# memory usage: 164.0 bytes

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1817 entries, 0 to 1816
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   VIX                             1817 non-null   float64
#  1   T-Bill_13W_Yield                1817 non-null   float64
#  2   10Y_Treasury_Yield              1817 non-null   float64
#  3   Credit_Spread                   1817 non-null   float64
#  4   Regime                          1817 non-null   object
#  5   VIX_lag_1                       1817 non-null   float64
#  6   VIX_lag_5                       1817 non-null   float64
#  7   VIX_lag_10                      1817 non-null   float64
#  8   T-Bill_13W_Yield_lag_1          1817 non-null   float64
#  9   T-Bill_13W_Yield_lag_5          1817 non-null   float64
#  10  T-Bill_13W_Yield_lag_10         1817 non-null   float64
#  11  10Y_Treasury_Yield_lag_1        1817 non-null   float64
# ...

# %%
df_main.describe()
# Out:
#                VIX  T-Bill_13W_Yield  10Y_Treasury_Yield  Credit_Spread  \
# count  1817.000000       1817.000000         1817.000000    1817.000000
# mean     20.022746          0.999346            2.502043       1.502697
# std       5.098609          0.198614            0.288476       0.348621
# min       3.685516          0.289908            1.543891       0.242011
# 25%      16.684176          0.862310            2.309891       1.278592
# 50%      20.072549          0.999196            2.506396       1.501573
# 75%      23.560675          1.137696            2.699557       1.743321
# max      35.069549          1.728127            3.444251       2.637945
#
#          VIX_lag_1    VIX_lag_5   VIX_lag_10  T-Bill_13W_Yield_lag_1  \
# count  1817.000000  1817.000000  1817.000000             1817.000000
# mean     20.026072    20.027682    20.038214                0.999262
# std       5.101173     5.096218     5.095483                0.198587
# ...

# %% [markdown]
# # Convert Date Column to Datetime Format

# %%
df_main['Date'] = pd.to_datetime(df_main['Date'], dayfirst=True)

# %% [markdown]
# # Check for Duplicates

# %%
dup_rows = df_main.duplicated().sum()

# %%
dup_rows
# Out:
# 0

# %% [markdown]
# no duplicates found

# %% [markdown]
# # Check for Missing Values

# %%
missing_values = df_main.isnull().sum()

# %%
missing_values
# Out:
# VIX                               0
# T-Bill_13W_Yield                  0
# 10Y_Treasury_Yield                0
# Credit_Spread                     0
# Regime                            0
# VIX_lag_1                         0
# VIX_lag_5                         0
# VIX_lag_10                        0
# T-Bill_13W_Yield_lag_1            0
# T-Bill_13W_Yield_lag_5            0
# T-Bill_13W_Yield_lag_10           0
# 10Y_Treasury_Yield_lag_1          0
# 10Y_Treasury_Yield_lag_5          0
# 10Y_Treasury_Yield_lag_10         0
# Credit_Spread_lag_1               0
# Credit_Spread_lag_5               0
# Credit_Spread_lag_10              0
# VIX_MA_(window)                   0
# T-Bill_13W_Yield_MA_(window)      0
# 10Y_Treasury_Yield_MA_(window)    0
# Credit_Spread_MA_(window)         0
# VIX_vol_5                         0
# VIX_vol_10                        0
# Yield_Curve_Steepness             0
# VIX_pct_change                    0
# Credit_Spread_pct_change          0
# ...

# %% [markdown]
# # Check Date Continuity & Frequency

# %%
df_main['Date'].min(), df_main['Date'].max()
# Out:
# (Timestamp('2018-01-01 00:00:00'), Timestamp('2024-12-31 00:00:00'))

# %%
df_main['Date'].diff().value_counts()
# Out:
# Date
# 1 days    1461
# 3 days     365
# Name: count, dtype: int64

# %% [markdown]
# "Date continuity check confirmed 1461 daily intervals and 365 3-day gaps, corresponding to weekend closures. No unusual gaps detected."

# %% [markdown]
# # Detect Outliers & Anomalies (Visual Check)

# %%
import matplotlib.pyplot as plt
df_main.set_index('Date')[['VIX', 'T-Bill_13W_Yield', '10Y_Treasury_Yield', 'Credit_Spread']].plot(subplots=True, figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
df_main.info()
df_main.isnull().sum()
df_main.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1827 entries, 0 to 1826
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                1827 non-null   datetime64[ns]
#  1   VIX                 1827 non-null   float64
#  2   T-Bill_13W_Yield    1827 non-null   float64
#  3   10Y_Treasury_Yield  1827 non-null   float64
#  4   Credit_Spread       1827 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 71.5 KB
# 0

# %%
df_main
# Out:
#             Date        VIX  T-Bill_13W_Yield  10Y_Treasury_Yield  \
# 0     01/01/2018  16.753388          1.013793            2.300598
# 1     02/01/2018  22.121129          0.921702            1.925130
# 2     03/01/2018  21.063509          1.045979            3.093456
# 3     04/01/2018  22.412022          0.887613            2.315705
# 4     05/01/2018  26.179142          0.607334            2.611276
# ...          ...        ...               ...                 ...
# 1822  25/12/2024  23.730057          0.888315            2.450349
# 1823  26/12/2024  12.689504          1.084723            2.805043
# 1824  27/12/2024  20.521115          1.228188            2.517219
# 1825  30/12/2024  10.472274          0.823259            2.495359
# 1826  31/12/2024  20.932712          1.139627            2.556615
#
#       Credit_Spread
# 0          1.286806
# 1          1.003428
# 2          2.047477
# 3          1.428092
# 4          2.003943
# ...             ...
# 1822       1.562035
# ...
